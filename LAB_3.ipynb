# %%
# !pip install -U google-genai

from google import genai

client = genai.Client(api_key="AQ.Ab8RN6LROtMI1WKiLLq3j6lRh9Vcvx2vP2wLfB8nsVKqyZx4uw")


MODEL = "models/gemini-3.5-flash"


def lecture_assistant(user_input):

    prompt = f"""
You are a professional AI Lecture Assistant for university students.

Your job is to help students understand and revise their lecture material.

For every lecture/topic provided by the student, give a well-structured response
with clear headings:

1. Lecture Summary
2. Important Key Points
3. Simple Explanation
4. Important Definitions
5. Short Questions & Answers
6. MCQs with 4 options and correct answer
7. Quick Revision Notes

Rules:
- Use simple and easy English.
- Explain difficult concepts in student-friendly language.
- Keep the information relevant to the given lecture/topic.
- Do not add unrelated information.
- If the student asks a specific question, answer it clearly.
- If the provided material is incomplete, mention that clearly.

Student's Lecture/Question:
{user_input}

AI Lecture Assistant Response:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text


print("AI Lecture Assistant Started (type 'exit' to stop)\n")

while True:
    user = input("Student: ")

    if user.lower() == "exit":
        print("Goodbye! Keep studying 📚")
        break

    try:
        reply = lecture_assistant(user)
        print("\nAI Lecture Assistant:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 19.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.49.0
#     Uninstalling google-auth-2.49.0:
#       Successfully uninstalled google-auth-2.49.0
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 2.12.1
#     Uninstalling google-genai-2.12.1:
#       Successfully uninstalled google-genai-2.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.58.0 which is incompatible.
# ...
# AI Lecture Assistant Started (type 'exit' to stop)
#
# Student: What is Artificial Intelligent?
# ...
